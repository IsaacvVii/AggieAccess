# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.12.2)

# %%
import requests
from bs4 import BeautifulSoup
import json

# URL of the UC Davis Electrical Engineering course catalog
URL = "https://catalog.ucdavis.edu/courses-subject-code/eec/"

# Request the page
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")

# List to store extracted course data
course_data = []

# Find all course containers (adjust class if needed)
course_sections = soup.find_all("div", class_="courseblock")

for course in course_sections:
    # Extract Course ID (EEC 234A, EEC 150, etc.)
    course_id_section = course.find("span", class_="text courseblockdetail detail-code margin--span text--semibold text--big")
    course_id = course_id_section.text.strip() if course_id_section else "N/A"

    # Extract Course Title
    title_section = course.find("span", class_="text courseblockdetail detail-title margin--span text--semibold text--big")
    course_title = title_section.text.strip() if title_section else "N/A"

    # Extract Course Units
    units_section = course.find("span", class_="text courseblockdetail detail-hours_html margin--span text--semibold text--big")
    course_units = units_section.text.strip() if units_section else "N/A"

    # Extract Course Description
    desc_section = course.find("div", class_="courseblockextra noindent")
    course_desc = desc_section.text.strip() if desc_section else "N/A"

    # Extract Prerequisites
    prereq_section = course.find("p", class_="text courseblockdetail detail-prerequisite")
    course_prereqs = prereq_section.text.strip() if prereq_section else "N/A"

    if prereq_section and "Prerequisite" in prereq_section.text:
        course_prereqs = prereq_section.text.replace("Prerequisite(s):", "").strip()

    # Store structured course data
    course_data.append({
        "course_id": course_id,
        "title": course_title,
        "units": course_units,
        "description": course_desc,
        "prerequisites": course_prereqs
    })

# Save to JSON for later use
with open("ucd_eec_courses.json", "w") as f:
    json.dump(course_data, f, indent=4)

print("Scraping complete. Data saved to 'ucd_eec_courses.json'.")
# Out:
# Scraping complete. Data saved to 'ucd_eec_courses.json'.

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# List of all UC Davis major abbreviations
majors = [
    "AAS", "ABG", "ABI", "ABT", "ACC", "AED", "AGC", "AHI", "AMS", "ANB", "ANE", "ANG", "ANS", "ANT", "APC", "ARB", "ARE", "ART", "ASA", "AST", "ATM", "AVS", "BAX", "BCB", "BCM", "BIM", "BIS", "BIT", "BPH", "BPT", "BST",
    "CAR", "CDM", "CGS", "CHA", "CHE", "CHI", "CHN", "CLA", "CLH", "CMN", "CNS", "COM", "CRD", "CRI", "CST", "CTS", "DEB", "DER", "DES", "DRA", "DSC", "DVM", "EAD", "EAE", "EAP", "EAS", "EBS", "ECH", "ECI", "ECL", "ECN",
    "ECS", "EDU", "EEC", "EGG", "EME", "EMR", "EMS", "ENG", "ENH", "ENL", "ENM", "ENT", "ENV", "EPI", "ESM", "ESP", "ETX", "EVE", "EVH", "EXB", "EXS", "FAH", "FAP", "FMS", "FOR", "FPS", "FRE", "FRS", "FSE", "FSM", "FST",
    "GAS", "GDB", "GEL", "GEO", "GER", "GGG", "GLO", "GMD", "GRD", "GRK", "GSW", "HDE", "HEB", "HIN", "HIS", "HMR", "HND", "HNR", "HON", "HPH", "HRT", "HUM", "HYD", "IAD", "ICL", "IDI", "IMD", "IMM", "IRE", "IST", "ITA",
    "JPN", "JST", "LAT", "LAW", "LDA", "LED", "LIN", "LTS", "MAE", "MAT", "MCB", "MCN", "MCP", "MDD", "MDS", "MGB", "MGP", "MGT", "MGV", "MHI", "MIB", "MIC", "MMG", "MMI", "MPM", "MSA", "MSC", "MST", "MUS", "NAS", "NEM",
    "NEP", "NEU", "NPB", "NRS", "NSC", "NSU", "NUB", "NUT", "OBG", "OPT", "OSU", "OTO", "PAS", "PBG", "PBI", "PDF", "PED", "PER", "PFS", "PHA", "PHI", "PHR", "PHY", "PLB", "PLP", "PLS", "PMD", "PMI", "PMR", "POL", "POR",
    "PSC", "PSU", "PSY", "PTX", "PUL", "PUN", "RAL", "RDI", "REL", "RNU", "RON", "RST", "RUS", "SAF", "SAS", "SOC", "SPA", "SPH", "SSB", "SSC", "STA", "STH", "STS", "SUR", "TAE", "TCS", "TTP", "TXC", "URD", "URO", "UWP",
    "VEN", "VET", "VMB", "VME", "VSR", "WAS", "WFC", "WLD", "WMS"
]


# Base URL pattern for UC Davis course catalog
BASE_URL = "https://catalog.ucdavis.edu/courses-subject-code/{}/"

def scrape_major_courses(major):
    """Scrapes all courses for a given major and saves to a JSON file."""
    url = BASE_URL.format(major.lower())  # Convert major abbreviation to lowercase for URL
    print(f"Scraping {major} from {url}...")

    # Request the page
    response = requests.get(url)

    # Check if page is valid
    if response.status_code != 200:
        print(f"Failed to retrieve {major}. Skipping...")
        return None

    soup = BeautifulSoup(response.text, "html.parser")

    course_data = []

    # Find all course containers
    course_sections = soup.find_all("div", class_="courseblock")

    for course in course_sections:
        # Extract Course ID (e.g., ECS 150, EEC 234A)
        course_id_section = course.find("span", class_="text courseblockdetail detail-code margin--span text--semibold text--big")
        course_id = course_id_section.text.strip() if course_id_section else "N/A"

        # Extract Course Title
        title_section = course.find("span", class_="text courseblockdetail detail-title margin--span text--semibold text--big")
        course_title = title_section.text.strip() if title_section else "N/A"

        # Extract Course Units
        units_section = course.find("span", class_="text courseblockdetail detail-hours_html margin--span text--semibold text--big")
        course_units = units_section.text.strip() if units_section else "N/A"

        # Extract Course Description
        desc_section = course.find("div", class_="courseblockextra noindent")
        course_desc = desc_section.text.strip() if desc_section else "N/A"

        # Extract Prerequisites
        prereq_section = course.find("p", class_="text courseblockdetail detail-prerequisite")
        course_prereqs = prereq_section.text.strip() if prereq_section else "N/A"

        if prereq_section and "Prerequisite" in prereq_section.text:
            course_prereqs = prereq_section.text.replace("Prerequisite(s):", "").strip()

        # Store structured data
        course_data.append({
            "course_id": course_id,
            "title": course_title,
            "units": course_units,
            "description": course_desc,
            "prerequisites": course_prereqs
        })

    # Save each major's course data to a JSON file
    filename = f"ucd_courses_{major}.json"
    with open(filename, "w") as f:
        json.dump(course_data, f, indent=4)

    print(f"✅ Saved {len(course_data)} courses for {major} in {filename}")

    return course_data

# Loop through each major and scrape courses
for major in majors:
    scrape_major_courses(major)
    time.sleep(1)  # Prevent rate-limiting

print("🎉 Scraping complete for all majors!")
# Out:
# Scraping AAS from https://catalog.ucdavis.edu/courses-subject-code/aas/...
# ✅ Saved 75 courses for AAS in ucd_courses_AAS.json
# Scraping ABG from https://catalog.ucdavis.edu/courses-subject-code/abg/...
# ✅ Saved 16 courses for ABG in ucd_courses_ABG.json
# Scraping ABI from https://catalog.ucdavis.edu/courses-subject-code/abi/...
# ✅ Saved 14 courses for ABI in ucd_courses_ABI.json
# Scraping ABT from https://catalog.ucdavis.edu/courses-subject-code/abt/...
# ✅ Saved 27 courses for ABT in ucd_courses_ABT.json
# Scraping ACC from https://catalog.ucdavis.edu/courses-subject-code/acc/...
# ✅ Saved 17 courses for ACC in ucd_courses_ACC.json
# Scraping AED from https://catalog.ucdavis.edu/courses-subject-code/aed/...
# ✅ Saved 19 courses for AED in ucd_courses_AED.json
# Scraping AGC from https://catalog.ucdavis.edu/courses-subject-code/agc/...
# ✅ Saved 3 courses for AGC in ucd_courses_AGC.json
# Scraping AHI from https://catalog.ucdavis.edu/courses-subject-code/ahi/...
# ✅ Saved 94 courses for AHI in ucd_courses_AHI.json
# Scraping AMS from https://catalog.ucdavis.edu/courses-subject-code/ams/...
# ✅ Saved 48 courses for AMS in ucd_courses_AMS.json
# Scraping ANB from https://catalog.ucdavis.edu/courses-subject-code/anb/...
# ✅ Saved 14 courses for ANB in ucd_courses_ANB.json
# Scraping ANE from https://catalog.ucdavis.edu/courses-subject-code/ane/...
# ✅ Saved 18 courses for ANE in ucd_courses_ANE.json
# Scraping ANG from https://catalog.ucdavis.edu/courses-subject-code/ang/...
# ✅ Saved 14 courses for ANG in ucd_courses_ANG.json
# Scraping ANS from https://catalog.ucdavis.edu/courses-subject-code/ans/...
# ✅ Saved 93 courses for ANS in ucd_courses_ANS.json
# Scraping ANT from https://catalog.ucdavis.edu/courses-subject-code/ant/...
# ✅ Saved 158 courses for ANT in ucd_courses_ANT.json
# Scraping APC from https://catalog.ucdavis.edu/courses-subject-code/apc/...
# ✅ Saved 11 courses for APC in ucd_courses_APC.json
# Scraping ARB from https://catalog.ucdavis.edu/courses-subject-code/arb/...
# ✅ Saved 28 courses for ARB in ucd_courses_ARB.json
# Scraping ARE from https://catalog.ucdavis.edu/courses-subject-code/are/...
# ✅ Saved 95 courses for ARE in ucd_courses_ARE.json
# Scraping ART from https://catalog.ucdavis.edu/courses-subject-code/art/...
# ✅ Saved 89 courses for ART in ucd_courses_ART.json
# Scraping ASA from https://catalog.ucdavis.edu/courses-subject-code/asa/...
# ✅ Saved 45 courses for ASA in ucd_courses_ASA.json
# Scraping AST from https://catalog.ucdavis.edu/courses-subject-code/ast/...
# ✅ Saved 5 courses for AST in ucd_courses_AST.json
# Scraping ATM from https://catalog.ucdavis.edu/courses-subject-code/atm/...
# ✅ Saved 60 courses for ATM in ucd_courses_ATM.json
# Scraping AVS from https://catalog.ucdavis.edu/courses-subject-code/avs/...
# ✅ Saved 31 courses for AVS in ucd_courses_AVS.json
# Scraping BAX from https://catalog.ucdavis.edu/courses-subject-code/bax/...
# ✅ Saved 22 courses for BAX in ucd_courses_BAX.json
# Scraping BCB from https://catalog.ucdavis.edu/courses-subject-code/bcb/...
# ✅ Saved 15 courses for BCB in ucd_courses_BCB.json
# Scraping BCM from https://catalog.ucdavis.edu/courses-subject-code/bcm/...
# ✅ Saved 18 courses for BCM in ucd_courses_BCM.json
# Scraping BIM from https://catalog.ucdavis.edu/courses-subject-code/bim/...
# ✅ Saved 116 courses for BIM in ucd_courses_BIM.json
# Scraping BIS from https://catalog.ucdavis.edu/courses-subject-code/bis/...
# ✅ Saved 48 courses for BIS in ucd_courses_BIS.json
# Scraping BIT from https://catalog.ucdavis.edu/courses-subject-code/bit/...
# ✅ Saved 16 courses for BIT in ucd_courses_BIT.json
# Scraping BPH from https://catalog.ucdavis.edu/courses-subject-code/bph/...
# ✅ Saved 14 courses for BPH in ucd_courses_BPH.json
# Scraping BPT from https://catalog.ucdavis.edu/courses-subject-code/bpt/...
# ✅ Saved 2 courses for BPT in ucd_courses_BPT.json
# Scraping BST from https://catalog.ucdavis.edu/courses-subject-code/bst/...
# ✅ Saved 11 courses for BST in ucd_courses_BST.json
# Scraping CAR from https://catalog.ucdavis.edu/courses-subject-code/car/...
# ✅ Saved 13 courses for CAR in ucd_courses_CAR.json
# Scraping CDM from https://catalog.ucdavis.edu/courses-subject-code/cdm/...
# ✅ Saved 61 courses for CDM in ucd_courses_CDM.json
# Scraping CGS from https://catalog.ucdavis.edu/courses-subject-code/cgs/...
# ✅ Saved 12 courses for CGS in ucd_courses_CGS.json
# Scraping CHA from https://catalog.ucdavis.edu/courses-subject-code/cha/...
# ✅ Saved 22 courses for CHA in ucd_courses_CHA.json
# Scraping CHE from https://catalog.ucdavis.edu/courses-subject-code/che/...
# ✅ Saved 122 courses for CHE in ucd_courses_CHE.json
# Scraping CHI from https://catalog.ucdavis.edu/courses-subject-code/chi/...
# ✅ Saved 77 courses for CHI in ucd_courses_CHI.json
# Scraping CHN from https://catalog.ucdavis.edu/courses-subject-code/chn/...
# ✅ Saved 64 courses for CHN in ucd_courses_CHN.json
# Scraping CLA from https://catalog.ucdavis.edu/courses-subject-code/cla/...
# ✅ Saved 66 courses for CLA in ucd_courses_CLA.json
# Scraping CLH from https://catalog.ucdavis.edu/courses-subject-code/clh/...
# ✅ Saved 33 courses for CLH in ucd_courses_CLH.json
# Scraping CMN from https://catalog.ucdavis.edu/courses-subject-code/cmn/...
# ✅ Saved 107 courses for CMN in ucd_courses_CMN.json
# Scraping CNS from https://catalog.ucdavis.edu/courses-subject-code/cns/...
# ✅ Saved 7 courses for CNS in ucd_courses_CNS.json
# Scraping COM from https://catalog.ucdavis.edu/courses-subject-code/com/...
# ✅ Saved 116 courses for COM in ucd_courses_COM.json
# Scraping CRD from https://catalog.ucdavis.edu/courses-subject-code/crd/...
# ✅ Saved 56 courses for CRD in ucd_courses_CRD.json
# Scraping CRI from https://catalog.ucdavis.edu/courses-subject-code/cri/...
# ✅ Saved 8 courses for CRI in ucd_courses_CRI.json
# Scraping CST from https://catalog.ucdavis.edu/courses-subject-code/cst/...
# ✅ Saved 19 courses for CST in ucd_courses_CST.json
# Scraping CTS from https://catalog.ucdavis.edu/courses-subject-code/cts/...
# ✅ Saved 8 courses for CTS in ucd_courses_CTS.json
# Scraping DEB from https://catalog.ucdavis.edu/courses-subject-code/deb/...
# ✅ Saved 3 courses for DEB in ucd_courses_DEB.json
# Scraping DER from https://catalog.ucdavis.edu/courses-subject-code/der/...
# ✅ Saved 13 courses for DER in ucd_courses_DER.json
# Scraping DES from https://catalog.ucdavis.edu/courses-subject-code/des/...
# ✅ Saved 102 courses for DES in ucd_courses_DES.json
# Scraping DRA from https://catalog.ucdavis.edu/courses-subject-code/dra/...
# ✅ Saved 139 courses for DRA in ucd_courses_DRA.json
# Scraping DSC from https://catalog.ucdavis.edu/courses-subject-code/dsc/...
# ✅ Saved 3 courses for DSC in ucd_courses_DSC.json
# Scraping DVM from https://catalog.ucdavis.edu/courses-subject-code/dvm/...
# ✅ Saved 0 courses for DVM in ucd_courses_DVM.json
# Scraping EAD from https://catalog.ucdavis.edu/courses-subject-code/ead/...
# ✅ Saved 19 courses for EAD in ucd_courses_EAD.json
# Scraping EAE from https://catalog.ucdavis.edu/courses-subject-code/eae/...
# ✅ Saved 19 courses for EAE in ucd_courses_EAE.json
# Scraping EAP from https://catalog.ucdavis.edu/courses-subject-code/eap/...
# ✅ Saved 5 courses for EAP in ucd_courses_EAP.json
# Scraping EAS from https://catalog.ucdavis.edu/courses-subject-code/eas/...
# ✅ Saved 8 courses for EAS in ucd_courses_EAS.json
# Scraping EBS from https://catalog.ucdavis.edu/courses-subject-code/ebs/...
# ✅ Saved 68 courses for EBS in ucd_courses_EBS.json
# Scraping ECH from https://catalog.ucdavis.edu/courses-subject-code/ech/...
# ✅ Saved 82 courses for ECH in ucd_courses_ECH.json
# Scraping ECI from https://catalog.ucdavis.edu/courses-subject-code/eci/...
# ✅ Saved 162 courses for ECI in ucd_courses_ECI.json
# Scraping ECL from https://catalog.ucdavis.edu/courses-subject-code/ecl/...
# ✅ Saved 28 courses for ECL in ucd_courses_ECL.json
# Scraping ECN from https://catalog.ucdavis.edu/courses-subject-code/ecn/...
# ✅ Saved 126 courses for ECN in ucd_courses_ECN.json
# Scraping ECS from https://catalog.ucdavis.edu/courses-subject-code/ecs/...
# ✅ Saved 178 courses for ECS in ucd_courses_ECS.json
# Scraping EDU from https://catalog.ucdavis.edu/courses-subject-code/edu/...
# ✅ Saved 162 courses for EDU in ucd_courses_EDU.json
# Scraping EEC from https://catalog.ucdavis.edu/courses-subject-code/eec/...
# ✅ Saved 208 courses for EEC in ucd_courses_EEC.json
# Scraping EGG from https://catalog.ucdavis.edu/courses-subject-code/egg/...
# ✅ Saved 7 courses for EGG in ucd_courses_EGG.json
# Scraping EME from https://catalog.ucdavis.edu/courses-subject-code/eme/...
# ✅ Saved 41 courses for EME in ucd_courses_EME.json
# Scraping EMR from https://catalog.ucdavis.edu/courses-subject-code/emr/...
# ✅ Saved 25 courses for EMR in ucd_courses_EMR.json
# Scraping EMS from https://catalog.ucdavis.edu/courses-subject-code/ems/...
# ✅ Saved 59 courses for EMS in ucd_courses_EMS.json
# Scraping ENG from https://catalog.ucdavis.edu/courses-subject-code/eng/...
# ✅ Saved 36 courses for ENG in ucd_courses_ENG.json
# Scraping ENH from https://catalog.ucdavis.edu/courses-subject-code/enh/...
# ✅ Saved 10 courses for ENH in ucd_courses_ENH.json
# Scraping ENL from https://catalog.ucdavis.edu/courses-subject-code/enl/...
# ✅ Saved 160 courses for ENL in ucd_courses_ENL.json
# Scraping ENM from https://catalog.ucdavis.edu/courses-subject-code/enm/...
# ✅ Saved 6 courses for ENM in ucd_courses_ENM.json
# Scraping ENT from https://catalog.ucdavis.edu/courses-subject-code/ent/...
# ✅ Saved 48 courses for ENT in ucd_courses_ENT.json
# Scraping ENV from https://catalog.ucdavis.edu/courses-subject-code/env/...
# ✅ Saved 15 courses for ENV in ucd_courses_ENV.json
# Scraping EPI from https://catalog.ucdavis.edu/courses-subject-code/epi/...
# ✅ Saved 33 courses for EPI in ucd_courses_EPI.json
# Scraping ESM from https://catalog.ucdavis.edu/courses-subject-code/esm/...
# ✅ Saved 25 courses for ESM in ucd_courses_ESM.json
# Scraping ESP from https://catalog.ucdavis.edu/courses-subject-code/esp/...
# ✅ Saved 59 courses for ESP in ucd_courses_ESP.json
# Scraping ETX from https://catalog.ucdavis.edu/courses-subject-code/etx/...
# ✅ Saved 55 courses for ETX in ucd_courses_ETX.json
# Scraping EVE from https://catalog.ucdavis.edu/courses-subject-code/eve/...
# ✅ Saved 62 courses for EVE in ucd_courses_EVE.json
# Scraping EVH from https://catalog.ucdavis.edu/courses-subject-code/evh/...
# ✅ Saved 1 courses for EVH in ucd_courses_EVH.json
# Scraping EXB from https://catalog.ucdavis.edu/courses-subject-code/exb/...
# ✅ Saved 30 courses for EXB in ucd_courses_EXB.json
# Scraping EXS from https://catalog.ucdavis.edu/courses-subject-code/exs/...
# ✅ Saved 1 courses for EXS in ucd_courses_EXS.json
# Scraping FAH from https://catalog.ucdavis.edu/courses-subject-code/fah/...
# ✅ Saved 2 courses for FAH in ucd_courses_FAH.json
# Scraping FAP from https://catalog.ucdavis.edu/courses-subject-code/fap/...
# ✅ Saved 51 courses for FAP in ucd_courses_FAP.json
# Scraping FMS from https://catalog.ucdavis.edu/courses-subject-code/fms/...
# ✅ Saved 11 courses for FMS in ucd_courses_FMS.json
# Scraping FOR from https://catalog.ucdavis.edu/courses-subject-code/for/...
# ✅ Saved 30 courses for FOR in ucd_courses_FOR.json
# Scraping FPS from https://catalog.ucdavis.edu/courses-subject-code/fps/...
# ✅ Saved 16 courses for FPS in ucd_courses_FPS.json
# Scraping FRE from https://catalog.ucdavis.edu/courses-subject-code/fre/...
# ✅ Saved 95 courses for FRE in ucd_courses_FRE.json
# Scraping FRS from https://catalog.ucdavis.edu/courses-subject-code/frs/...
# ✅ Saved 4 courses for FRS in ucd_courses_FRS.json
# Scraping FSE from https://catalog.ucdavis.edu/courses-subject-code/fse/...
# ✅ Saved 5 courses for FSE in ucd_courses_FSE.json
# Scraping FSM from https://catalog.ucdavis.edu/courses-subject-code/fsm/...
# ✅ Saved 7 courses for FSM in ucd_courses_FSM.json
# Scraping FST from https://catalog.ucdavis.edu/courses-subject-code/fst/...
# ✅ Saved 60 courses for FST in ucd_courses_FST.json
# Scraping GAS from https://catalog.ucdavis.edu/courses-subject-code/gas/...
# ✅ Saved 5 courses for GAS in ucd_courses_GAS.json
# Scraping GDB from https://catalog.ucdavis.edu/courses-subject-code/gdb/...
# ✅ Saved 8 courses for GDB in ucd_courses_GDB.json
# Scraping GEL from https://catalog.ucdavis.edu/courses-subject-code/gel/...
# ✅ Saved 139 courses for GEL in ucd_courses_GEL.json
# Scraping GEO from https://catalog.ucdavis.edu/courses-subject-code/geo/...
# ✅ Saved 35 courses for GEO in ucd_courses_GEO.json
# Scraping GER from https://catalog.ucdavis.edu/courses-subject-code/ger/...
# ✅ Saved 103 courses for GER in ucd_courses_GER.json
# Scraping GGG from https://catalog.ucdavis.edu/courses-subject-code/ggg/...
# ✅ Saved 22 courses for GGG in ucd_courses_GGG.json
# Scraping GLO from https://catalog.ucdavis.edu/courses-subject-code/glo/...
# ✅ Saved 4 courses for GLO in ucd_courses_GLO.json
# Scraping GMD from https://catalog.ucdavis.edu/courses-subject-code/gmd/...
# ✅ Saved 6 courses for GMD in ucd_courses_GMD.json
# Scraping GRD from https://catalog.ucdavis.edu/courses-subject-code/grd/...
# ✅ Saved 5 courses for GRD in ucd_courses_GRD.json
# Scraping GRK from https://catalog.ucdavis.edu/courses-subject-code/grk/...
# ✅ Saved 27 courses for GRK in ucd_courses_GRK.json
# Scraping GSW from https://catalog.ucdavis.edu/courses-subject-code/gsw/...
# ✅ Saved 26 courses for GSW in ucd_courses_GSW.json
# Scraping HDE from https://catalog.ucdavis.edu/courses-subject-code/hde/...
# ✅ Saved 66 courses for HDE in ucd_courses_HDE.json
# Scraping HEB from https://catalog.ucdavis.edu/courses-subject-code/heb/...
# ✅ Saved 17 courses for HEB in ucd_courses_HEB.json
# Scraping HIN from https://catalog.ucdavis.edu/courses-subject-code/hin/...
# ✅ Saved 10 courses for HIN in ucd_courses_HIN.json
# Scraping HIS from https://catalog.ucdavis.edu/courses-subject-code/his/...
# ✅ Saved 269 courses for HIS in ucd_courses_HIS.json
# Scraping HMR from https://catalog.ucdavis.edu/courses-subject-code/hmr/...
# ✅ Saved 27 courses for HMR in ucd_courses_HMR.json
# Scraping HND from https://catalog.ucdavis.edu/courses-subject-code/hnd/...
# ✅ Saved 5 courses for HND in ucd_courses_HND.json
# Scraping HNR from https://catalog.ucdavis.edu/courses-subject-code/hnr/...
# ✅ Saved 11 courses for HNR in ucd_courses_HNR.json
# Scraping HON from https://catalog.ucdavis.edu/courses-subject-code/hon/...
# ✅ Saved 9 courses for HON in ucd_courses_HON.json
# Scraping HPH from https://catalog.ucdavis.edu/courses-subject-code/hph/...
# ✅ Saved 21 courses for HPH in ucd_courses_HPH.json
# Scraping HRT from https://catalog.ucdavis.edu/courses-subject-code/hrt/...
# ✅ Saved 7 courses for HRT in ucd_courses_HRT.json
# Scraping HUM from https://catalog.ucdavis.edu/courses-subject-code/hum/...
# ✅ Saved 27 courses for HUM in ucd_courses_HUM.json
# Scraping HYD from https://catalog.ucdavis.edu/courses-subject-code/hyd/...
# ✅ Saved 43 courses for HYD in ucd_courses_HYD.json
# Scraping IAD from https://catalog.ucdavis.edu/courses-subject-code/iad/...
# ✅ Saved 20 courses for IAD in ucd_courses_IAD.json
# Scraping ICL from https://catalog.ucdavis.edu/courses-subject-code/icl/...
# ✅ Saved 49 courses for ICL in ucd_courses_ICL.json
# Scraping IDI from https://catalog.ucdavis.edu/courses-subject-code/idi/...
# ✅ Saved 11 courses for IDI in ucd_courses_IDI.json
# Scraping IMD from https://catalog.ucdavis.edu/courses-subject-code/imd/...
# ✅ Saved 59 courses for IMD in ucd_courses_IMD.json
# Scraping IMM from https://catalog.ucdavis.edu/courses-subject-code/imm/...
# ✅ Saved 15 courses for IMM in ucd_courses_IMM.json
# Scraping IRE from https://catalog.ucdavis.edu/courses-subject-code/ire/...
# ✅ Saved 10 courses for IRE in ucd_courses_IRE.json
# Scraping IST from https://catalog.ucdavis.edu/courses-subject-code/ist/...
# ✅ Saved 11 courses for IST in ucd_courses_IST.json
# Scraping ITA from https://catalog.ucdavis.edu/courses-subject-code/ita/...
# ✅ Saved 74 courses for ITA in ucd_courses_ITA.json
# Scraping JPN from https://catalog.ucdavis.edu/courses-subject-code/jpn/...
# ✅ Saved 69 courses for JPN in ucd_courses_JPN.json
# Scraping JST from https://catalog.ucdavis.edu/courses-subject-code/jst/...
# ✅ Saved 8 courses for JST in ucd_courses_JST.json
# Scraping LAT from https://catalog.ucdavis.edu/courses-subject-code/lat/...
# ✅ Saved 29 courses for LAT in ucd_courses_LAT.json
# Scraping LAW from https://catalog.ucdavis.edu/courses-subject-code/law/...
# ✅ Saved 413 courses for LAW in ucd_courses_LAW.json
# Scraping LDA from https://catalog.ucdavis.edu/courses-subject-code/lda/...
# ✅ Saved 53 courses for LDA in ucd_courses_LDA.json
# Scraping LED from https://catalog.ucdavis.edu/courses-subject-code/led/...
# ✅ Saved 3 courses for LED in ucd_courses_LED.json
# Scraping LIN from https://catalog.ucdavis.edu/courses-subject-code/lin/...
# ✅ Saved 78 courses for LIN in ucd_courses_LIN.json
# Scraping LTS from https://catalog.ucdavis.edu/courses-subject-code/lts/...
# ✅ Saved 8 courses for LTS in ucd_courses_LTS.json
# Scraping MAE from https://catalog.ucdavis.edu/courses-subject-code/mae/...
# ✅ Saved 53 courses for MAE in ucd_courses_MAE.json
# Scraping MAT from https://catalog.ucdavis.edu/courses-subject-code/mat/...
# ✅ Saved 148 courses for MAT in ucd_courses_MAT.json
# Scraping MCB from https://catalog.ucdavis.edu/courses-subject-code/mcb/...
# ✅ Saved 50 courses for MCB in ucd_courses_MCB.json
# Scraping MCN from https://catalog.ucdavis.edu/courses-subject-code/mcn/...
# ✅ Saved 8 courses for MCN in ucd_courses_MCN.json
# Scraping MCP from https://catalog.ucdavis.edu/courses-subject-code/mcp/...
# ✅ Saved 30 courses for MCP in ucd_courses_MCP.json
# Scraping MDD from https://catalog.ucdavis.edu/courses-subject-code/mdd/...
# ✅ Saved 2 courses for MDD in ucd_courses_MDD.json
# Scraping MDS from https://catalog.ucdavis.edu/courses-subject-code/mds/...
# ✅ Saved 105 courses for MDS in ucd_courses_MDS.json
# Scraping MGB from https://catalog.ucdavis.edu/courses-subject-code/mgb/...
# ✅ Saved 162 courses for MGB in ucd_courses_MGB.json
# Scraping MGP from https://catalog.ucdavis.edu/courses-subject-code/mgp/...
# ✅ Saved 162 courses for MGP in ucd_courses_MGP.json
# Scraping MGT from https://catalog.ucdavis.edu/courses-subject-code/mgt/...
# ✅ Saved 176 courses for MGT in ucd_courses_MGT.json
# Scraping MGV from https://catalog.ucdavis.edu/courses-subject-code/mgv/...
# ✅ Saved 68 courses for MGV in ucd_courses_MGV.json
# Scraping MHI from https://catalog.ucdavis.edu/courses-subject-code/mhi/...
# ✅ Saved 17 courses for MHI in ucd_courses_MHI.json
# Scraping MIB from https://catalog.ucdavis.edu/courses-subject-code/mib/...
# ✅ Saved 6 courses for MIB in ucd_courses_MIB.json
# Scraping MIC from https://catalog.ucdavis.edu/courses-subject-code/mic/...
# ✅ Saved 38 courses for MIC in ucd_courses_MIC.json
# Scraping MMG from https://catalog.ucdavis.edu/courses-subject-code/mmg/...
# ✅ Saved 3 courses for MMG in ucd_courses_MMG.json
# Scraping MMI from https://catalog.ucdavis.edu/courses-subject-code/mmi/...
# ✅ Saved 25 courses for MMI in ucd_courses_MMI.json
# Scraping MPM from https://catalog.ucdavis.edu/courses-subject-code/mpm/...
# ✅ Saved 12 courses for MPM in ucd_courses_MPM.json
# Scraping MSA from https://catalog.ucdavis.edu/courses-subject-code/msa/...
# ✅ Saved 28 courses for MSA in ucd_courses_MSA.json
# Scraping MSC from https://catalog.ucdavis.edu/courses-subject-code/msc/...
# ✅ Saved 25 courses for MSC in ucd_courses_MSC.json
# Scraping MST from https://catalog.ucdavis.edu/courses-subject-code/mst/...
# ✅ Saved 17 courses for MST in ucd_courses_MST.json
# Scraping MUS from https://catalog.ucdavis.edu/courses-subject-code/mus/...
# ✅ Saved 141 courses for MUS in ucd_courses_MUS.json
# Scraping NAS from https://catalog.ucdavis.edu/courses-subject-code/nas/...
# ✅ Saved 90 courses for NAS in ucd_courses_NAS.json
# Scraping NEM from https://catalog.ucdavis.edu/courses-subject-code/nem/...
# ✅ Saved 15 courses for NEM in ucd_courses_NEM.json
# Scraping NEP from https://catalog.ucdavis.edu/courses-subject-code/nep/...
# ✅ Saved 5 courses for NEP in ucd_courses_NEP.json
# Scraping NEU from https://catalog.ucdavis.edu/courses-subject-code/neu/...
# ✅ Saved 14 courses for NEU in ucd_courses_NEU.json
# Scraping NPB from https://catalog.ucdavis.edu/courses-subject-code/npb/...
# ✅ Saved 101 courses for NPB in ucd_courses_NPB.json
# Scraping NRS from https://catalog.ucdavis.edu/courses-subject-code/nrs/...
# ✅ Saved 176 courses for NRS in ucd_courses_NRS.json
# Scraping NSC from https://catalog.ucdavis.edu/courses-subject-code/nsc/...
# ✅ Saved 36 courses for NSC in ucd_courses_NSC.json
# Scraping NSU from https://catalog.ucdavis.edu/courses-subject-code/nsu/...
# ✅ Saved 12 courses for NSU in ucd_courses_NSU.json
# Scraping NUB from https://catalog.ucdavis.edu/courses-subject-code/nub/...
# ✅ Saved 6 courses for NUB in ucd_courses_NUB.json
# Scraping NUT from https://catalog.ucdavis.edu/courses-subject-code/nut/...
# ✅ Saved 59 courses for NUT in ucd_courses_NUT.json
# Scraping OBG from https://catalog.ucdavis.edu/courses-subject-code/obg/...
# ✅ Saved 31 courses for OBG in ucd_courses_OBG.json
# Scraping OPT from https://catalog.ucdavis.edu/courses-subject-code/opt/...
# ✅ Saved 7 courses for OPT in ucd_courses_OPT.json
# Scraping OSU from https://catalog.ucdavis.edu/courses-subject-code/osu/...
# ✅ Saved 11 courses for OSU in ucd_courses_OSU.json
# Scraping OTO from https://catalog.ucdavis.edu/courses-subject-code/oto/...
# ✅ Saved 13 courses for OTO in ucd_courses_OTO.json
# Scraping PAS from https://catalog.ucdavis.edu/courses-subject-code/pas/...
# ✅ Saved 33 courses for PAS in ucd_courses_PAS.json
# Scraping PBG from https://catalog.ucdavis.edu/courses-subject-code/pbg/...
# ✅ Saved 24 courses for PBG in ucd_courses_PBG.json
# Scraping PBI from https://catalog.ucdavis.edu/courses-subject-code/pbi/...
# ✅ Saved 21 courses for PBI in ucd_courses_PBI.json
# Scraping PDF from https://catalog.ucdavis.edu/courses-subject-code/pdf/...
# Failed to retrieve PDF. Skipping...
# Scraping PED from https://catalog.ucdavis.edu/courses-subject-code/ped/...
# ✅ Saved 48 courses for PED in ucd_courses_PED.json
# Scraping PER from https://catalog.ucdavis.edu/courses-subject-code/per/...
# ✅ Saved 17 courses for PER in ucd_courses_PER.json
# Scraping PFS from https://catalog.ucdavis.edu/courses-subject-code/pfs/...
# ✅ Saved 15 courses for PFS in ucd_courses_PFS.json
# Scraping PHA from https://catalog.ucdavis.edu/courses-subject-code/pha/...
# ✅ Saved 21 courses for PHA in ucd_courses_PHA.json
# Scraping PHI from https://catalog.ucdavis.edu/courses-subject-code/phi/...
# ✅ Saved 110 courses for PHI in ucd_courses_PHI.json
# Scraping PHR from https://catalog.ucdavis.edu/courses-subject-code/phr/...
# ✅ Saved 17 courses for PHR in ucd_courses_PHR.json
# Scraping PHY from https://catalog.ucdavis.edu/courses-subject-code/phy/...
# ✅ Saved 147 courses for PHY in ucd_courses_PHY.json
# Scraping PLB from https://catalog.ucdavis.edu/courses-subject-code/plb/...
# ✅ Saved 29 courses for PLB in ucd_courses_PLB.json
# Scraping PLP from https://catalog.ucdavis.edu/courses-subject-code/plp/...
# ✅ Saved 27 courses for PLP in ucd_courses_PLP.json
# Scraping PLS from https://catalog.ucdavis.edu/courses-subject-code/pls/...
# ✅ Saved 90 courses for PLS in ucd_courses_PLS.json
# Scraping PMD from https://catalog.ucdavis.edu/courses-subject-code/pmd/...
# ✅ Saved 24 courses for PMD in ucd_courses_PMD.json
# Scraping PMI from https://catalog.ucdavis.edu/courses-subject-code/pmi/...
# ✅ Saved 19 courses for PMI in ucd_courses_PMI.json
# Scraping PMR from https://catalog.ucdavis.edu/courses-subject-code/pmr/...
# ✅ Saved 17 courses for PMR in ucd_courses_PMR.json
# Scraping POL from https://catalog.ucdavis.edu/courses-subject-code/pol/...
# ✅ Saved 175 courses for POL in ucd_courses_POL.json
# Scraping POR from https://catalog.ucdavis.edu/courses-subject-code/por/...
# ✅ Saved 25 courses for POR in ucd_courses_POR.json
# Scraping PSC from https://catalog.ucdavis.edu/courses-subject-code/psc/...
# ✅ Saved 140 courses for PSC in ucd_courses_PSC.json
# Scraping PSU from https://catalog.ucdavis.edu/courses-subject-code/psu/...
# ✅ Saved 1 courses for PSU in ucd_courses_PSU.json
# Scraping PSY from https://catalog.ucdavis.edu/courses-subject-code/psy/...
# ✅ Saved 43 courses for PSY in ucd_courses_PSY.json
# Scraping PTX from https://catalog.ucdavis.edu/courses-subject-code/ptx/...
# ✅ Saved 9 courses for PTX in ucd_courses_PTX.json
# Scraping PUL from https://catalog.ucdavis.edu/courses-subject-code/pul/...
# ✅ Saved 10 courses for PUL in ucd_courses_PUL.json
# Scraping PUN from https://catalog.ucdavis.edu/courses-subject-code/pun/...
# ✅ Saved 11 courses for PUN in ucd_courses_PUN.json
# Scraping RAL from https://catalog.ucdavis.edu/courses-subject-code/ral/...
# ✅ Saved 11 courses for RAL in ucd_courses_RAL.json
# Scraping RDI from https://catalog.ucdavis.edu/courses-subject-code/rdi/...
# ✅ Saved 15 courses for RDI in ucd_courses_RDI.json
# Scraping REL from https://catalog.ucdavis.edu/courses-subject-code/rel/...
# ✅ Saved 19 courses for REL in ucd_courses_REL.json
# Scraping RNU from https://catalog.ucdavis.edu/courses-subject-code/rnu/...
# ✅ Saved 8 courses for RNU in ucd_courses_RNU.json
# Scraping RON from https://catalog.ucdavis.edu/courses-subject-code/ron/...
# ✅ Saved 8 courses for RON in ucd_courses_RON.json
# Scraping RST from https://catalog.ucdavis.edu/courses-subject-code/rst/...
# ✅ Saved 105 courses for RST in ucd_courses_RST.json
# Scraping RUS from https://catalog.ucdavis.edu/courses-subject-code/rus/...
# ✅ Saved 36 courses for RUS in ucd_courses_RUS.json
# Scraping SAF from https://catalog.ucdavis.edu/courses-subject-code/saf/...
# ✅ Saved 13 courses for SAF in ucd_courses_SAF.json
# Scraping SAS from https://catalog.ucdavis.edu/courses-subject-code/sas/...
# ✅ Saved 53 courses for SAS in ucd_courses_SAS.json
# Scraping SOC from https://catalog.ucdavis.edu/courses-subject-code/soc/...
# ✅ Saved 115 courses for SOC in ucd_courses_SOC.json
# Scraping SPA from https://catalog.ucdavis.edu/courses-subject-code/spa/...
# ✅ Saved 159 courses for SPA in ucd_courses_SPA.json
# Scraping SPH from https://catalog.ucdavis.edu/courses-subject-code/sph/...
# ✅ Saved 79 courses for SPH in ucd_courses_SPH.json
# Scraping SSB from https://catalog.ucdavis.edu/courses-subject-code/ssb/...
# ✅ Saved 3 courses for SSB in ucd_courses_SSB.json
# Scraping SSC from https://catalog.ucdavis.edu/courses-subject-code/ssc/...
# ✅ Saved 25 courses for SSC in ucd_courses_SSC.json
# Scraping STA from https://catalog.ucdavis.edu/courses-subject-code/sta/...
# ✅ Saved 90 courses for STA in ucd_courses_STA.json
# Scraping STH from https://catalog.ucdavis.edu/courses-subject-code/sth/...
# ✅ Saved 4 courses for STH in ucd_courses_STH.json
# Scraping STS from https://catalog.ucdavis.edu/courses-subject-code/sts/...
# ✅ Saved 64 courses for STS in ucd_courses_STS.json
# Scraping SUR from https://catalog.ucdavis.edu/courses-subject-code/sur/...
# ✅ Saved 40 courses for SUR in ucd_courses_SUR.json
# Scraping TAE from https://catalog.ucdavis.edu/courses-subject-code/tae/...
# ✅ Saved 13 courses for TAE in ucd_courses_TAE.json
# Scraping TCS from https://catalog.ucdavis.edu/courses-subject-code/tcs/...
# ✅ Saved 6 courses for TCS in ucd_courses_TCS.json
# Scraping TTP from https://catalog.ucdavis.edu/courses-subject-code/ttp/...
# ✅ Saved 18 courses for TTP in ucd_courses_TTP.json
# Scraping TXC from https://catalog.ucdavis.edu/courses-subject-code/txc/...
# ✅ Saved 15 courses for TXC in ucd_courses_TXC.json
# Scraping URD from https://catalog.ucdavis.edu/courses-subject-code/urd/...
# ✅ Saved 5 courses for URD in ucd_courses_URD.json
# Scraping URO from https://catalog.ucdavis.edu/courses-subject-code/uro/...
# ✅ Saved 5 courses for URO in ucd_courses_URO.json
# Scraping UWP from https://catalog.ucdavis.edu/courses-subject-code/uwp/...
# ✅ Saved 93 courses for UWP in ucd_courses_UWP.json
# Scraping VEN from https://catalog.ucdavis.edu/courses-subject-code/ven/...
# ✅ Saved 53 courses for VEN in ucd_courses_VEN.json
# Scraping VET from https://catalog.ucdavis.edu/courses-subject-code/vet/...
# ✅ Saved 40 courses for VET in ucd_courses_VET.json
# Scraping VMB from https://catalog.ucdavis.edu/courses-subject-code/vmb/...
# ✅ Saved 15 courses for VMB in ucd_courses_VMB.json
# Scraping VME from https://catalog.ucdavis.edu/courses-subject-code/vme/...
# ✅ Saved 11 courses for VME in ucd_courses_VME.json
# Scraping VSR from https://catalog.ucdavis.edu/courses-subject-code/vsr/...
# ✅ Saved 4 courses for VSR in ucd_courses_VSR.json
# Scraping WAS from https://catalog.ucdavis.edu/courses-subject-code/was/...
# ✅ Saved 4 courses for WAS in ucd_courses_WAS.json
# Scraping WFC from https://catalog.ucdavis.edu/courses-subject-code/wfc/...
# ✅ Saved 62 courses for WFC in ucd_courses_WFC.json
# Scraping WLD from https://catalog.ucdavis.edu/courses-subject-code/wld/...
# ✅ Saved 26 courses for WLD in ucd_courses_WLD.json
# Scraping WMS from https://catalog.ucdavis.edu/courses-subject-code/wms/...
# ✅ Saved 24 courses for WMS in ucd_courses_WMS.json
# 🎉 Scraping complete for all majors!

# %%
import pandas as pd
import json
import glob
import os

# Define the directory where JSON files are stored
data_dir = "/content/"

# Function to clean and process data
def clean_units(units):
    return units.replace('(', '').replace(')', '').replace(' units', '') if isinstance(units, str) else None

def clean_prerequisites(prerequisites):
    return prerequisites.replace('\u00a0', ' ') if isinstance(prerequisites, str) else None

def clean_title(title):
    return title.replace('\u2014', '').strip() if isinstance(title, str) else None

def classify_course_level(course_id):
    try:
        course_number = int(''.join(filter(str.isdigit, course_id)))
        if course_number < 100:
            return 'Lower Division'
        elif 100 <= course_number < 200:
            return 'Upper Division'
        else:
            return 'Graduate Level'
    except ValueError:
        return 'Unknown'

# Function to process all JSON files
def process_all_courses(data_dir):
    all_courses = []
    json_files = glob.glob(os.path.join(data_dir, "ucd_courses_*.json"))

    for file_path in json_files:
        major = os.path.basename(file_path).replace("ucd_courses_", "").replace(".json", "")

        with open(file_path, 'r', encoding='utf-8') as f:
            courses = json.load(f)

        df = pd.DataFrame(courses)

        # Ensure required columns exist before processing
        df['units'] = df['units'].apply(clean_units) if 'units' in df else None
        df['title'] = df['title'].apply(clean_title) if 'title' in df else None
        df['prerequisites'] = df['prerequisites'].apply(clean_prerequisites) if 'prerequisites' in df else None
        df['course_level'] = df['course_id'].apply(classify_course_level) if 'course_id' in df else None
        df['major'] = major  # Add the major column

        all_courses.append(df)

    return pd.concat(all_courses, ignore_index=True) if all_courses else pd.DataFrame()

# Process all JSON files
df_all_courses = process_all_courses(data_dir)

# Display the cleaned DataFrame
df_all_courses.head()
# Out:
#   course_id                                title units  \
# 0  MST 020A               Early Medieval Culture     4
# 1  MST 020B  The Culture of the High Middle Ages     4
# 2   MST 098                 Directed Group Study   1-5
# 3  MST 098F           Student Facilitated Course   1-4
# 4   MST 099     Special Study for Undergraduates   1-5
#
#                                          description           prerequisites  \
# 0  Learning Activities: Lecture 3 hour(s), Extens...                     N/A
# 1  Learning Activities: Lecture 3 hour(s), Extens...                     N/A
# 2  Learning Activities: Variable.\nGrade Mode: Pa...                     N/A
# 3  Learning Activities: Variable 1-4 hour(s).\nGr...  Consent of instructor.
# 4  Learning Activities: Variable.\nGrade Mode: Pa...                     N/A
#
#      course_level major
# 0  Lower Division   MST
# 1  Lower Division   MST
# 2  Lower Division   MST
# 3  Lower Division   MST
# 4  Lower Division   MST

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_all_courses)
# Out:
# https://docs.google.com/spreadsheets/d/1uADnqDvhh2fyQLQJNoZCCKQ3wsgZQRcogbvnk_9tJ6w#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1uADnqDvhh2fyQLQJNoZCCKQ3wsgZQRcogbvnk_9tJ6w#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
